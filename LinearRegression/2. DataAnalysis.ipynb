# %% [markdown]
# # Import Essentials

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ---
# # Reading from .CSV file

# %%
data = pd.read_csv("datasets/boston_housing.csv")
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# ---
#  # Describes the data

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ---
# # Outputs first 5 elements

# %%
data.head(5)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# ---
# # Outputs last 5 elements

# %%
data.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT  MEDV
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %% [markdown]
# ---
# # Access data under 0x1 cell [row,column]

# %%
data.iloc[0,1]
# Out:
# np.float64(18.0)

# %% [markdown]
# ---
#  # Access 69:75 rows with 4:10 columns

# %%
data.iloc[69:75, 4:10]
# Out:
#       NOX     RM   AGE     DIS  RAD  TAX
# 69  0.409  5.885  33.0  6.4980    4  345
# 70  0.413  6.417   6.6  5.2873    4  305
# 71  0.413  5.961  17.5  5.2873    4  305
# 72  0.413  6.065   7.8  5.2873    4  305
# 73  0.413  6.245   6.2  5.2873    4  305
# 74  0.437  6.273   6.0  4.2515    5  398

# %% [markdown]
#  ---
#  # Access 0:5 rows with all columns

# %%
data[5:15]
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 5   0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222
# 6   0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311
# 7   0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311
# 8   0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
# 12  0.09378  12.5   7.87     0  0.524  5.889   39.0  5.4509    5  311
# 13  0.62976   0.0   8.14     0  0.538  5.949   61.8  4.7075    4  307
# 14  0.63796   0.0   8.14     0  0.538  6.096   84.5  4.4619    4  307
#
#     PTRATIO       B  LSTAT  MEDV
# 5      18.7  394.12   5.21  28.7
# 6      15.2  395.60  12.43  22.9
# 7      15.2  396.90  19.15  27.1
# 8      15.2  386.63  29.93  16.5
# ...

# %% [markdown]
# ---
# # Access rows with condition(s)

# %%
data[(data.MEDV < 15.0) & (data.RAD == 5)]
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 142  3.32105  0.0  19.58     1  0.871  5.403  100.0  1.3216    5  403
# 144  2.77974  0.0  19.58     0  0.871  4.903   97.8  1.3459    5  403
# 145  2.37934  0.0  19.58     0  0.871  6.130  100.0  1.4191    5  403
# 147  2.36862  0.0  19.58     0  0.871  4.926   95.7  1.4608    5  403
# 156  2.44668  0.0  19.58     0  0.871  5.272   94.0  1.7364    5  403
#
#      PTRATIO       B  LSTAT  MEDV
# 142     14.7  396.90  26.82  13.4
# 144     14.7  396.90  29.29  11.8
# 145     14.7  172.91  27.80  13.8
# 147     14.7  391.71  29.53  14.6
# 156     14.7   88.63  16.14  13.1

# %% [markdown]
# ---
# # Changing the values of the column (does apply to orginal dataframe)

# %%
data.iloc[5:10,3:4]+=100
data.iloc[5:10,3:4]
# Out:
#    CHAS
# 5   100
# 6   100
# 7   100
# 8   100
# 9   100

# %% [markdown]
# ---
# # Accessing by column name

# %%
data[["CRIM", "RAD"]]
# Out:
#         CRIM  RAD
# 0    0.00632    1
# 1    0.02731    2
# 2    0.02729    2
# 3    0.03237    3
# 4    0.06905    3
# ..       ...  ...
# 501  0.06263    1
# 502  0.04527    1
# 503  0.06076    1
# 504  0.10959    1
# 505  0.04741    1
#
# [506 rows x 2 columns]

# %% [markdown]
# ---
# # To check if column exist

# %%
"MEDV" in data
# Out:
# True

# %% [markdown]
# ---
# # Acessing rows with specific column names

# %%
data.loc[4:10, ["LSTAT","MEDV"]]
# Out:
#     LSTAT  MEDV
# 4    5.33  36.2
# 5    5.21  28.7
# 6   12.43  22.9
# 7   19.15  27.1
# 8   29.93  16.5
# 9   17.10  18.9
# 10  20.45  15.0

# %% [markdown]
# ---
# # Accesing with query conditioning

# %%
data.query("MEDV < 20.0 and TAX == 311")
# Out:
#        CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 8   0.21124  12.5   7.87   100  0.524  5.631  100.0  6.0821    5  311
# 9   0.17004  12.5   7.87   100  0.524  6.004   85.9  6.5921    5  311
# 10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311
# 11  0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311
#
#     PTRATIO       B  LSTAT  MEDV
# 8      15.2  386.63  29.93  16.5
# 9      15.2  386.71  17.10  18.9
# 10     15.2  392.52  20.45  15.0
# 11     15.2  396.90  13.27  18.9

# %% [markdown]
# ---
# # Making subset from other dataset

# %%
data_subset = data[["AGE","TAX","MEDV"]] 
data_subset
# Out:
#       AGE  TAX  MEDV
# 0    65.2  296  24.0
# 1    78.9  242  21.6
# 2    61.1  242  34.7
# 3    45.8  222  33.4
# 4    54.2  222  36.2
# ..    ...  ...   ...
# 501  69.1  273  22.4
# 502  76.7  273  20.6
# 503  91.0  273  23.9
# 504  89.3  273  22.0
# 505  80.8  273  11.9
#
# [506 rows x 3 columns]

# %% [markdown]
# ---
# # 'apply(func)' - applying the 'func' to row/column
#
# You can choose what to apply it for:
# - axis=0 -> columns (default);
# - axis=1 -> rows

# %%
data_subset.apply(max, axis=0)
# Out:
# AGE     100.0
# TAX     711.0
# MEDV     50.0
# dtype: float64

# %% [markdown]
# ---
# # Using lambda is fine (Duh ???)

# %%
data_subset.apply(lambda row: row*2, axis=1)
# Out:
#        AGE    TAX  MEDV
# 0    130.4  592.0  48.0
# 1    157.8  484.0  43.2
# 2    122.2  484.0  69.4
# 3     91.6  444.0  66.8
# 4    108.4  444.0  72.4
# ..     ...    ...   ...
# 501  138.2  546.0  44.8
# 502  153.4  546.0  41.2
# 503  182.0  546.0  47.8
# 504  178.6  546.0  44.0
# 505  161.6  546.0  23.8
#
# [506 rows x 3 columns]

# %% [markdown]
# ---
# # 'where(condition, value)' - conditional formatting (by each row)
#
# Keeps all rows that vaildate the condition, rest with be changed into 'np.nan'

# %%
data_subset = data_subset.where(data_subset.TAX > 250, np.nan)

# %% [markdown]
# ---
# # 'map' - conditional formatting (by each cell)

# %%
data_subset.map(lambda x: round(x) if type(x)!=type(np.nan) else x)
# Out:
#       AGE    TAX  MEDV
# 0    65.2  296.0  24.0
# 1     NaN    NaN   NaN
# 2     NaN    NaN   NaN
# 3     NaN    NaN   NaN
# 4     NaN    NaN   NaN
# ..    ...    ...   ...
# 501  69.1  273.0  22.4
# 502  76.7  273.0  20.6
# 503  91.0  273.0  23.9
# 504  89.3  273.0  22.0
# 505  80.8  273.0  11.9
#
# [506 rows x 3 columns]

# %% [markdown]
# ---
#  # Fills 'NaN' values with '-1'

# %%
data_subset.fillna(-1)
# Out:
#       AGE    TAX  MEDV
# 0    65.2  296.0  24.0
# 1    -1.0   -1.0  -1.0
# 2    -1.0   -1.0  -1.0
# 3    -1.0   -1.0  -1.0
# 4    -1.0   -1.0  -1.0
# ..    ...    ...   ...
# 501  69.1  273.0  22.4
# 502  76.7  273.0  20.6
# 503  91.0  273.0  23.9
# 504  89.3  273.0  22.0
# 505  80.8  273.0  11.9
#
# [506 rows x 3 columns]

# %% [markdown]
# ---
# # Fills 'NaN' depending on elements around it

# %%
data_subset.interpolate()
# Out:
#            AGE    TAX       MEDV
# 0    65.200000  296.0  24.000000
# 1    65.433333  298.5  23.816667
# 2    65.666667  301.0  23.633333
# 3    65.900000  303.5  23.450000
# 4    66.133333  306.0  23.266667
# ..         ...    ...        ...
# 501  69.100000  273.0  22.400000
# 502  76.700000  273.0  20.600000
# 503  91.000000  273.0  23.900000
# 504  89.300000  273.0  22.000000
# 505  80.800000  273.0  11.900000
#
# [506 rows x 3 columns]

# %% [markdown]
# ---
# # Plotting the data set visually
#
# **kind : str**
#
# - ‘line’ : line plot (default)
# - ‘bar’ : vertical bar plot
# - ‘barh’ : horizontal bar plot
# - ‘hist’ : histogram
# - ‘box’ : boxplot
# - ‘kde’ : Kernel Density Estimation plot
# - ‘density’ : same as ‘kde’
# - ‘area’ : area plot
# - ‘pie’ : pie plot
# - ‘scatter’ : scatter plot
# - ‘hexbin’ : hexbin plot

# %%
data_plot = data[:5].plot(kind="bar")
plt.title("Boston Housing")
plt.style.use("dark_background")
data_plot.set_xlabel("Features")
data_plot.set_ylabel("Count")
plt.show()

# %% [markdown]
# ---
# # Plotting Correlation Matrix
#
# sns.heatmap(annot=True) - Display exact correlation values

# %%
corr_matrix = data.corr()
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Bostong Housing Matrix")
plt.show()

# %% [markdown]
# ---
# # Pairplotting with Seaborn

# %%
selected_features = ['RM', 'ZN', 'DIS', 'B', 'LSTAT', 'MEDV']
sns.pairplot(data[selected_features])
plt.suptitle("Boston Pairplot")
plt.show()
